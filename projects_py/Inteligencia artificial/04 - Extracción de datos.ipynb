# %% [markdown]
# # Extraccion de datos Python
# ## Web scraping
# Se requiere el modulo BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# %%
# Enlace a la pagina de consulta
url = 'https://es.wikipedia.org/wiki/Organizaci%C3%B3n_territorial_de_Guatemala'

# %%
response = requests.get(url)

# %%
print('Status code', url, ':', response.status_code)
# Out:
# Status code https://es.wikipedia.org/wiki/Organizaci%C3%B3n_territorial_de_Guatemala : 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
tabla = soup.find('table', {'class': 'wikitable'})

# %%
dir(tabla)
# Out:
# ['DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_event_stream',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_namespaces',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'css',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'encode',
#  'encode_contents',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'known_xml',
#  'name',
#  'namespace',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parserClass',
#  'parser_class',
#  'prefix',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'sourceline',
#  'sourcepos',
#  'string',
#  'strings',
#  'stripped_strings',
#  'text',
#  'unwrap',
#  'wrap']

# %%
import pandas as pd

# %%
tabla = pd.read_html(str(tabla))
tabla
# Out:
# C:\Users\karol\AppData\Local\Temp\ipykernel_1348\650288738.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tabla = pd.read_html(str(tabla))
# [                                                    0  \
#  0                          Departamentos de Guatemala
#  1   Zacapa Chiquimula Sacatepéquez San Marcos Reta...
#  2                                        Departamento
#  3                                        Alta Verapaz
#  4                                        Baja Verapaz
#  5                                       Chimaltenango
#  6                                          Chiquimula
#  7                                         El Progreso
#  8                                           Escuintla
#  9                                           Guatemala
#  10                                      Huehuetenango
#  11                                             Izabal
#  12                                             Jalapa
#  13                                            Jutiapa
#  14                                              Petén
#  15                                     Quetzaltenango
#  16                                             Quiché
#  17                                         Retalhuleu
#  18                                       Sacatepéquez
#  19                                         San Marcos
#  20                                         Santa Rosa
#  21                                             Sololá
#  22                                      Suchitepéquez
#  23                                        Totonicapán
#  24                                             Zacapa
#
#                                                      1  \
#  0                          Departamentos de Guatemala
#  1   Zacapa Chiquimula Sacatepéquez San Marcos Reta...
#  2                                            Cabecera
#  3                                               Cobán
#  4                                              Salamá
#  5                                       Chimaltenango
#  6                                          Chiquimula
#  7                                          Guastatoya
#  8                                           Escuintla
#  9                                 Ciudad de Guatemala
#  10                                      Huehuetenango
#  11                                     Puerto Barrios
#  12                                             Jalapa
#  13                                            Jutiapa
#  14                                             Flores
#  15                                     Quetzaltenango
#  16                              Santa Cruz del Quiché
#  17                                         Retalhuleu
#  18                                  Antigua Guatemala
#  19                                         San Marcos
#  20                                            Cuilapa
#  21                                             Sololá
#  22                                        Mazatenango
#  23                                        Totonicapán
#  24                                             Zacapa
#
#                                                      2  \
#  0                          Departamentos de Guatemala
#  1   Zacapa Chiquimula Sacatepéquez San Marcos Reta...
#  2                                    Superficie (km²)
#  3                                               8 686
#  4                                               3 124
#  5                                               1 979
#  6                                               2 376
#  7                                               1 922
#  8                                               4 384
#  9                                               2 126
#  10                                              7 400
#  11                                              9 038
#  12                                              2 063
#  13                                              3 216
#  14                                             35 854
#  15                                              1 953
#  16                                              8 378
#  17                                              1 856
#  18                                                465
#  19                                              3 791
#  20                                              2 955
#  21                                              1 061
#  22                                              2 510
#  23                                              1 061
#  24                                              2 690
#
#                                                      3
#  0                          Departamentos de Guatemala
#  1   Zacapa Chiquimula Sacatepéquez San Marcos Reta...
#  2                                Población (hab.)[1]​
#  3                                           1 112 781
#  4                                             270 521
#  5                                             666 938
#  6                                             370 891
#  7                                             158 092
#  8                                             701 016
#  9                                           2 541 581
#  10                                          1 143 887
#  11                                            413 399
#  12                                            318 420
#  13                                            436 076
#  14                                            638 296
#  15                                            789 358
#  16                                            953 027
#  17                                            304 168
#  18                                            248 019
#  19                                          1 019 719
#  20                                            346 590
#  21                                            437 145
#  22                                            516 467
#  23                                            476 369
#  24                                            221 646  ,
#        Departamento               Cabecera Superficie (km²)  \
#  0     Alta Verapaz                  Cobán            8 686
#  1     Baja Verapaz                 Salamá            3 124
#  2    Chimaltenango          Chimaltenango            1 979
#  3       Chiquimula             Chiquimula            2 376
#  4      El Progreso             Guastatoya            1 922
#  5        Escuintla              Escuintla            4 384
#  6        Guatemala    Ciudad de Guatemala            2 126
#  7    Huehuetenango          Huehuetenango            7 400
#  8           Izabal         Puerto Barrios            9 038
#  9           Jalapa                 Jalapa            2 063
#  10         Jutiapa                Jutiapa            3 216
#  11           Petén                 Flores           35 854
#  12  Quetzaltenango         Quetzaltenango            1 953
#  13          Quiché  Santa Cruz del Quiché            8 378
#  14      Retalhuleu             Retalhuleu            1 856
#  15    Sacatepéquez      Antigua Guatemala              465
#  16      San Marcos             San Marcos            3 791
#  17      Santa Rosa                Cuilapa            2 955
#  18          Sololá                 Sololá            1 061
#  19   Suchitepéquez            Mazatenango            2 510
#  20     Totonicapán            Totonicapán            1 061
#  21          Zacapa                 Zacapa            2 690
#
#     Población (hab.)[1]​
#  0             1 112 781
#  1               270 521
#  2               666 938
#  3               370 891
#  4               158 092
#  5               701 016
#  6             2 541 581
#  7             1 143 887
#  8               413 399
#  9               318 420
#  10              436 076
#  11              638 296
#  12              789 358
#  13              953 027
#  14              304 168
#  15              248 019
#  16            1 019 719
#  17              346 590
#  18              437 145
#  19              516 467
#  20              476 369
#  21              221 646  ]

# %%
departamento = tabla[1]

# %%
departamento
# Out:
#       Departamento               Cabecera Superficie (km²)  \
# 0     Alta Verapaz                  Cobán            8 686
# 1     Baja Verapaz                 Salamá            3 124
# 2    Chimaltenango          Chimaltenango            1 979
# 3       Chiquimula             Chiquimula            2 376
# 4      El Progreso             Guastatoya            1 922
# 5        Escuintla              Escuintla            4 384
# 6        Guatemala    Ciudad de Guatemala            2 126
# 7    Huehuetenango          Huehuetenango            7 400
# 8           Izabal         Puerto Barrios            9 038
# 9           Jalapa                 Jalapa            2 063
# 10         Jutiapa                Jutiapa            3 216
# 11           Petén                 Flores           35 854
# 12  Quetzaltenango         Quetzaltenango            1 953
# 13          Quiché  Santa Cruz del Quiché            8 378
# 14      Retalhuleu             Retalhuleu            1 856
# 15    Sacatepéquez      Antigua Guatemala              465
# 16      San Marcos             San Marcos            3 791
# 17      Santa Rosa                Cuilapa            2 955
# 18          Sololá                 Sololá            1 061
# 19   Suchitepéquez            Mazatenango            2 510
# 20     Totonicapán            Totonicapán            1 061
# 21          Zacapa                 Zacapa            2 690
#
#    Población (hab.)[1]​
# 0             1 112 781
# 1               270 521
# 2               666 938
# 3               370 891
# 4               158 092
# 5               701 016
# 6             2 541 581
# 7             1 143 887
# 8               413 399
# 9               318 420
# 10              436 076
# 11              638 296
# 12              789 358
# 13              953 027
# 14              304 168
# 15              248 019
# 16            1 019 719
# 17              346 590
# 18              437 145
# 19              516 467
# 20              476 369
# 21              221 646

# %%
departamento.columns = ['Departamento', 'Cabecera', 'Superficie', 'Poblacion']

# %%
departamento
# Out:
#       Departamento               Cabecera Superficie  Poblacion
# 0     Alta Verapaz                  Cobán      8 686  1 112 781
# 1     Baja Verapaz                 Salamá      3 124    270 521
# 2    Chimaltenango          Chimaltenango      1 979    666 938
# 3       Chiquimula             Chiquimula      2 376    370 891
# 4      El Progreso             Guastatoya      1 922    158 092
# 5        Escuintla              Escuintla      4 384    701 016
# 6        Guatemala    Ciudad de Guatemala      2 126  2 541 581
# 7    Huehuetenango          Huehuetenango      7 400  1 143 887
# 8           Izabal         Puerto Barrios      9 038    413 399
# 9           Jalapa                 Jalapa      2 063    318 420
# 10         Jutiapa                Jutiapa      3 216    436 076
# 11           Petén                 Flores     35 854    638 296
# 12  Quetzaltenango         Quetzaltenango      1 953    789 358
# 13          Quiché  Santa Cruz del Quiché      8 378    953 027
# 14      Retalhuleu             Retalhuleu      1 856    304 168
# 15    Sacatepéquez      Antigua Guatemala        465    248 019
# 16      San Marcos             San Marcos      3 791  1 019 719
# 17      Santa Rosa                Cuilapa      2 955    346 590
# 18          Sololá                 Sololá      1 061    437 145
# 19   Suchitepéquez            Mazatenango      2 510    516 467
# 20     Totonicapán            Totonicapán      1 061    476 369
# 21          Zacapa                 Zacapa      2 690    221 646

# %%
departamento.describe()
# Out:
#         Departamento Cabecera Superficie  Poblacion
# count             22       22         22         22
# unique            22       22         21         22
# top     Alta Verapaz    Cobán      1 061  1 112 781
# freq               1        1          2          1

# %%
region = soup.find_all('table')[2]
region = pd.read_html(str(region))[0]
region
# Out:
# C:\Users\karol\AppData\Local\Temp\ipykernel_1348\2730513204.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   region = pd.read_html(str(region))[0]
#                       Región  \
# 0  Suroccidente  (Región VI)
# 1   Metropolitana (Región I)
# 2  Noroccidente (Región VII)
# 3         Central (Región V)
# 4        Verapaz (Región II)
# 5    Nororiente (Región III)
# 6     Suroriente (Región IV)
# 7        Petén (Región VIII)
#
#                       Departamentos que la conforman  Extensión (km2)  \
# 0  Quetzaltenango  Retalhuleu  San Marcos  Sololá...            12232
# 1                                          Guatemala             2253
# 2                              Huehuetenango  Quiché            15778
# 3             Chimaltenango  Escuintla  Sacatepéquez             6828
# 4                         Alta Verapaz  Baja Verapaz            11810
# 5            Chiquimula  El Progreso  Izabal  Zacapa            16026
# 6                        Jalapa  Jutiapa  Santa Rosa             8234
# 7                                              Petén            35854
#
#    Población      Ciudad Más Poblada
# 0    4398222          Quetzaltenango
# 1    3573179     Ciudad de Guatemala
# 2    2686692           Huehuetenango
# 3    1991006               Escuintla
# 4    1790153                   Cobán
# 5    1410262          Puerto Barrios
# 6    1347255                  Jalapa
# 7     858256  Santa Elena de la Cruz

# %%
segeplan = soup.find_all('table')[3]
segeplan = pd.read_html(str(segeplan))[0]
# Out:
# C:\Users\karol\AppData\Local\Temp\ipykernel_1348\2575617158.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   segeplan = pd.read_html(str(segeplan))[0]

# %%
segeplan
# Out:
#                           Región Departamento(s)  \
# 0                          Petén           Petén
# 1   Franja Transversal del Norte   Huehuetenango
# 2   Franja Transversal del Norte          Izabal
# 3   Franja Transversal del Norte    Alta Verapaz
# 4   Franja Transversal del Norte          Quiché
# 5                 Región Oriente          Zacapa
# 6                 Región Oriente     El Progreso
# 7                 Región Oriente      Chiquimula
# 8                 Región Oriente          Izabal
# 9                 Región Oriente         Jutiapa
# 10                Región Oriente          Jalapa
# 11                Región Oriente      Santa Rosa
# 12          Litoral del Pacífico         Jutiapa
# 13          Litoral del Pacífico      Santa Rosa
# 14          Litoral del Pacífico       Escuintla
# 15          Litoral del Pacífico   Suchitepéquez
# 16          Litoral del Pacífico      Retalhuleu
# 17          Litoral del Pacífico      San Marcos
# 18          Litoral del Pacífico  Quetzaltenango
#
#                                            Municipios
# 0                                Todos los municipios
# 1   Jacaltenango, Santa Ana Huista, San Antonio Hu...
# 2   Puerto Barrios, Morales, Los Amates, El Estor ...
# 3   Cobán, San Pedro Carchá, Senahú, Lanquín, Caha...
# 4                           Ixcán, Uspantán y Chajul.
# 5                                Todos los municipios
# 6                                Todos los municipios
# 7                                Todos los municipios
# 8               Puerto Barrios, Morales y Los Amates.
# 9   Agua Blanca, Santa Catarina Mita, Asunción Mit...
# 10                               Todos los municipios
# 11  Santa Rosa de Lima, Nueva Santa Rosa, San Rafa...
# 12                                   Moyuta y Pasaco.
# 13               Chiquimulilla, Guazacapán y Taxisco.
# 14  Iztapa, San José, La Gomera, Nueva Concepción,...
# 15  Cuyotenango, Santo Domingo Suchitepéquez, San ...
# 16                               Todos los municipios
# 17      Ocós, Ayutla, Pajapita, Catarina y Malacatán.
# 18   Coatepeque, Génova, Colomba y Flores Costa Cuca.

# %%
subregion = soup.find_all('table')[4]

# %%
subregion = pd.read_html(str(subregion))[0]
# Out:
# C:\Users\karol\AppData\Local\Temp\ipykernel_1348\269097309.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   subregion = pd.read_html(str(subregion))[0]

# %%
subregion
# Out:
#             Subregión Departamento(s)  \
# 0  Subregión Polochic    Alta Verapaz
# 1  Subregión Polochic          Izabal
# 2  Subregión Polochic    Baja Verapaz
# 3              Xalalá          Quiché
# 4              Xalalá    Alta Verapaz
#
#                                  Municipios
# 0  Tucurú, Panzós, Senahú, Tactic y Tamahú.
# 1                    Livingston y El Estor.
# 2                                   Purulhá
# 3                         Ixcán y Uspantán.
# 4                                     Cobán

# %%
departamento.dtypes
# Out:
# Departamento    object
# Cabecera        object
# Superficie      object
# Poblacion       object
# dtype: object

# %%
departamento['Superficie'] = list(int(x.replace('\xa0', '')) for x in departamento['Superficie'])
departamento
# Out:
#       Departamento               Cabecera  Superficie  Poblacion
# 0     Alta Verapaz                  Cobán        8686  1 112 781
# 1     Baja Verapaz                 Salamá        3124    270 521
# 2    Chimaltenango          Chimaltenango        1979    666 938
# 3       Chiquimula             Chiquimula        2376    370 891
# 4      El Progreso             Guastatoya        1922    158 092
# 5        Escuintla              Escuintla        4384    701 016
# 6        Guatemala    Ciudad de Guatemala        2126  2 541 581
# 7    Huehuetenango          Huehuetenango        7400  1 143 887
# 8           Izabal         Puerto Barrios        9038    413 399
# 9           Jalapa                 Jalapa        2063    318 420
# 10         Jutiapa                Jutiapa        3216    436 076
# 11           Petén                 Flores       35854    638 296
# 12  Quetzaltenango         Quetzaltenango        1953    789 358
# 13          Quiché  Santa Cruz del Quiché        8378    953 027
# 14      Retalhuleu             Retalhuleu        1856    304 168
# 15    Sacatepéquez      Antigua Guatemala         465    248 019
# 16      San Marcos             San Marcos        3791  1 019 719
# 17      Santa Rosa                Cuilapa        2955    346 590
# 18          Sololá                 Sololá        1061    437 145
# 19   Suchitepéquez            Mazatenango        2510    516 467
# 20     Totonicapán            Totonicapán        1061    476 369
# 21          Zacapa                 Zacapa        2690    221 646

# %%
departamento['Poblacion'] = list(int(x.replace('\xa0', '')) for x in departamento['Poblacion'])
departamento
# Out:
#       Departamento               Cabecera  Superficie  Poblacion
# 0     Alta Verapaz                  Cobán        8686    1112781
# 1     Baja Verapaz                 Salamá        3124     270521
# 2    Chimaltenango          Chimaltenango        1979     666938
# 3       Chiquimula             Chiquimula        2376     370891
# 4      El Progreso             Guastatoya        1922     158092
# 5        Escuintla              Escuintla        4384     701016
# 6        Guatemala    Ciudad de Guatemala        2126    2541581
# 7    Huehuetenango          Huehuetenango        7400    1143887
# 8           Izabal         Puerto Barrios        9038     413399
# 9           Jalapa                 Jalapa        2063     318420
# 10         Jutiapa                Jutiapa        3216     436076
# 11           Petén                 Flores       35854     638296
# 12  Quetzaltenango         Quetzaltenango        1953     789358
# 13          Quiché  Santa Cruz del Quiché        8378     953027
# 14      Retalhuleu             Retalhuleu        1856     304168
# 15    Sacatepéquez      Antigua Guatemala         465     248019
# 16      San Marcos             San Marcos        3791    1019719
# 17      Santa Rosa                Cuilapa        2955     346590
# 18          Sololá                 Sololá        1061     437145
# 19   Suchitepéquez            Mazatenango        2510     516467
# 20     Totonicapán            Totonicapán        1061     476369
# 21          Zacapa                 Zacapa        2690     221646

# %%
region.columns = ['Region', 'Departamentos que la conforman', 'Extensión', 'Población', 'Ciudad Más Poblada']
region
# Out:
#                       Region  \
# 0  Suroccidente  (Región VI)
# 1   Metropolitana (Región I)
# 2  Noroccidente (Región VII)
# 3         Central (Región V)
# 4        Verapaz (Región II)
# 5    Nororiente (Región III)
# 6     Suroriente (Región IV)
# 7        Petén (Región VIII)
#
#                       Departamentos que la conforman  Extensión  Población  \
# 0  Quetzaltenango  Retalhuleu  San Marcos  Sololá...      12232    4398222
# 1                                          Guatemala       2253    3573179
# 2                              Huehuetenango  Quiché      15778    2686692
# 3             Chimaltenango  Escuintla  Sacatepéquez       6828    1991006
# 4                         Alta Verapaz  Baja Verapaz      11810    1790153
# 5            Chiquimula  El Progreso  Izabal  Zacapa      16026    1410262
# 6                        Jalapa  Jutiapa  Santa Rosa       8234    1347255
# 7                                              Petén      35854     858256
#
#        Ciudad Más Poblada
# 0          Quetzaltenango
# 1     Ciudad de Guatemala
# 2           Huehuetenango
# 3               Escuintla
# 4                   Cobán
# 5          Puerto Barrios
# 6                  Jalapa
# 7  Santa Elena de la Cruz

# %%
subregion.columns = ['Subregión', 'Departamento', 'Municipios']
subregion
# Out:
#             Subregión  Departamento                                Municipios
# 0  Subregión Polochic  Alta Verapaz  Tucurú, Panzós, Senahú, Tactic y Tamahú.
# 1  Subregión Polochic        Izabal                    Livingston y El Estor.
# 2  Subregión Polochic  Baja Verapaz                                   Purulhá
# 3              Xalalá        Quiché                         Ixcán y Uspantán.
# 4              Xalalá  Alta Verapaz                                     Cobán

# %%
segeplan.columns = ['Región', 'Departamento', 'Municipios']
segeplan
# Out:
#                           Región    Departamento  \
# 0                          Petén           Petén
# 1   Franja Transversal del Norte   Huehuetenango
# 2   Franja Transversal del Norte          Izabal
# 3   Franja Transversal del Norte    Alta Verapaz
# 4   Franja Transversal del Norte          Quiché
# 5                 Región Oriente          Zacapa
# 6                 Región Oriente     El Progreso
# 7                 Región Oriente      Chiquimula
# 8                 Región Oriente          Izabal
# 9                 Región Oriente         Jutiapa
# 10                Región Oriente          Jalapa
# 11                Región Oriente      Santa Rosa
# 12          Litoral del Pacífico         Jutiapa
# 13          Litoral del Pacífico      Santa Rosa
# 14          Litoral del Pacífico       Escuintla
# 15          Litoral del Pacífico   Suchitepéquez
# 16          Litoral del Pacífico      Retalhuleu
# 17          Litoral del Pacífico      San Marcos
# 18          Litoral del Pacífico  Quetzaltenango
#
#                                            Municipios
# 0                                Todos los municipios
# 1   Jacaltenango, Santa Ana Huista, San Antonio Hu...
# 2   Puerto Barrios, Morales, Los Amates, El Estor ...
# 3   Cobán, San Pedro Carchá, Senahú, Lanquín, Caha...
# 4                           Ixcán, Uspantán y Chajul.
# 5                                Todos los municipios
# 6                                Todos los municipios
# 7                                Todos los municipios
# 8               Puerto Barrios, Morales y Los Amates.
# 9   Agua Blanca, Santa Catarina Mita, Asunción Mit...
# 10                               Todos los municipios
# 11  Santa Rosa de Lima, Nueva Santa Rosa, San Rafa...
# 12                                   Moyuta y Pasaco.
# 13               Chiquimulilla, Guazacapán y Taxisco.
# 14  Iztapa, San José, La Gomera, Nueva Concepción,...
# 15  Cuyotenango, Santo Domingo Suchitepéquez, San ...
# 16                               Todos los municipios
# 17      Ocós, Ayutla, Pajapita, Catarina y Malacatán.
# 18   Coatepeque, Génova, Colomba y Flores Costa Cuca.
